# %% [markdown]
# <a href="https://colab.research.google.com/github/StacyChebet/Myntra-Sales/blob/main/Myntra_Sales_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![myntra.png](data:image/png;base64,...)
#
# # **🛍️ What This Notebook is About**
#
# In this notebook, I'll be performing **exploratory data analysis (EDA)** on the **Myntra Fashion Products Dataset** to uncover key insights into India's online fashion market. <br><br>
# Expect to see visualizations exploring **brand performance**, **pricing trends**, **discounts** and **customer ratings**, all aimed at understanding what drives product popularity on Myntra!<br><br>
# We'll dive deep into:
# - Which brands offer the best discounts and deals?
# - How do price and discount percentage relate to customer ratings?
# - Which products are most popular based on ratings and reviews?
# - How do fashion pricing trends vary across brands?
# - Fun and interactive visualizations showing brand-wise and price-based insights!<br><br>
# By the end, you'll have a clear snapshot of Myntra's fashion landscape: the brands customers love most, pricing strategies that work and how discounts influence purchase behavior.

# %%
#Importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#Setting visualization styles
sns.set(style="whitegrid")

#Mounting google drive
from google.colab import drive
drive.mount('/content/drive')

#Changing directory
# %cd /content/drive/My Drive/Colab Notebooks/Data Analytics - IBT/Myntra

#Loading the dataset
file_path = "myntra_dataset_ByScraping.csv"
df = pd.read_csv(file_path)

#Displaying the first few rows of the dataset
df.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/Colab Notebooks/Data Analytics - IBT/Myntra
#        brand_name           pants_description   price     MRP  \
# 0           WROGN  Men Loose Fit Cotton Jeans  1374.0  2499.0
# 1  Flying Machine          Men Slim Fit Jeans  1829.0  2999.0
# 2        Roadster       Men Pure Cotton Jeans   974.0  2499.0
# 3      Bene Kleed     Relaxed Fit Denim Jeans   873.0  2299.0
# 4           Levis      Men 511 Slim Fit Jeans  1478.0  2899.0
#
#    discount_percent  ratings  number_of_ratings
# 0              0.45      4.2               57.0
# 1              0.39      4.6                5.0
# 2              0.61      3.6             1100.0
# 3              0.62      4.0             4800.0
# 4              0.49      4.3              264.0
